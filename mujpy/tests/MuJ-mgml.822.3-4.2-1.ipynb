# %%
# %matplotlib ipympl

# %%
from os import getcwd
startuppath = getcwd()
from mujpy.musuite import suite
from mujpy.mudash import dash
from mujpy.mufit import mufit
from mujpy.mufitplot import mufitplot
from matplotlib.pyplot import show
datafile = '/home/roberto.derenzi/musrfit/MBT/gps/run_05_21/data/deltat_tdc_gps_0822.bin'
runlist = '822' # first run first
offset = '20'
grp_calib = [{'forward':'3', 'backward':'4', 'alpha':1.13},{'forward':'2', 'backward':'1', 'alpha':1.13}]
#
the_suite = suite(datafile, runlist , grp_calib , offset, startuppath)
dashboard_file = startuppath+'/fit/mgml.822.3-4.2-1.1_fit.json' # must exist
the_fit = mufit(the_suite,dashboard_file)
plot_range = '0,20000,40'
the_fitplot = mufitplot(plot_range,the_fit)
display()
# Out:
# ******************* SUITE *********************
# ~/musrfit/MBT/gps/run_05_21/data/deltat_tdc_gps_0822.bin loaded:
# Run 822: MnBi6Te10 pellet 30.0K 10mT
# Reading fit guess from: ./fit/mgml.822.3-4.2-1.1_fit.json
# |-----------------------------------------------------------------------------|
# | Run 822: MnBi6Te10 pellet 30.0K 10mT     α = 1.130  offs = 20  group: 3 - 4 |
# |χᵣ² = 1.045(0.939,1.065), on [7.83ns, 7.8µs] 15.63ns/bin @26/08/2026 10:41:34|
# |-----------------------------------------------------------------------------|
# | mgA_0 = 0.057(5) B_0 = 10.3(2)    φ_0 = 34.2(7)    σ_0 = 1.5(2)
# | mlA_1 = 0.195(6) B_1 = 10.023(5)  φ_1 = 34.2(7)s   λ_1 = 0.072(9)
# |_____________________________________________________________________________|
# 822 3-4:  row added to mgml.1_A20.csv
# ./fit/mgml.822.3-4.1_A20.json  saved.
# |-----------------------------------------------------------------------------|
# | Run 822: MnBi6Te10 pellet 30.0K 10mT     α = 1.130  offs = 20  group: 2 - 1 |
# |χᵣ² = 0.993(0.939,1.065), on [7.83ns, 7.8µs] 15.63ns/bin @26/08/2026 10:41:34|
# |-----------------------------------------------------------------------------|
# | mgA_0 = 0.051(7) B_0 = 9.0(5)     φ_0 = -53(1)     σ_0 = 2.1(3)
# | mlA_1 = 0.190(7) B_1 = 10.00(1)   φ_1 = -53(1)s    λ_1 = 0.07(1)
# |_____________________________________________________________________________|
# 822 2-1:  row added to mgml.1_A20.csv
# ./fit/mgml.822.2-1.1_A20.json  saved.
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
